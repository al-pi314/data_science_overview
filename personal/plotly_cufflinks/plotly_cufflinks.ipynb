# %%
import pandas as pd
import numpy as np
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.11.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True) # initalizies JS connection
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline() # selects offline server
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns='A B C D'.split())

# %%
df2 = pd.DataFrame({'Categories': ['A', 'B', 'C'], 'Values': [32, 43, 50]})

# %%
df.iplot()
# Out:
# <div>                            <div id="a21311fc-633f-42d3-86f1-1ea620970086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>                            <div id="83c53393-b768-4b0b-b350-3edd862a373c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar', x='Categories', y='Values')
# Out:
# <div>                            <div id="7f22c74b-a20b-4601-b701-57b7ac6a4bd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="51c1c2c2-5a9a-418b-bc73-863fc4e2ff4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="8348c1d8-c4e4-478c-a719-773b0e81e702" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y':[10, 20, 30, 20, 10], 'z':[5, 4, 3, 2, 1]})

# %%
df3.iplot
# Out:
# <bound method _iplot of    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100>

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>                            <div id="75bcd6eb-49d1-4b9f-8338-22d8ec85937f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist', bins=50)
# Out:
# <div>                            <div id="0e23e86e-dedb-4bc9-b9be-8c53bd10aaea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A', 'B']]
# Out:
#            A         B
# 0   0.255763 -0.765321
# 1  -0.268335  0.025947
# 2  -0.385124  1.763141
# 3   0.506293  0.287964
# 4  -0.795521  1.516429
# ..       ...       ...
# 95  2.735849 -0.038472
# 96 -0.097231  1.068179
# 97  0.120498 -1.008515
# 98 -0.993496 -0.388717
# 99  0.426770 -0.485716
#
# [100 rows x 2 columns]

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# c:\Users\Aleksander\anaconda3\envs\data_science_overview\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# c:\Users\Aleksander\anaconda3\envs\data_science_overview\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="995b6f2c-eade-4327-89c5-badc345e8d8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.255763 -0.765321  2.548023  0.087840
# 1 -0.268335  0.025947  0.009599 -0.887997
# 2 -0.385124  1.763141 -0.401645 -0.514534
# 3  0.506293  0.287964  0.269769 -2.079561
# 4 -0.795521  1.516429  1.929111  0.624598

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="f3d3cf3a-40e2-42b1-8bfb-f79ea3c828ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="e8fba0b5-0fca-46b3-8502-800dd9880572" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
